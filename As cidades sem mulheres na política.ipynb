# %% [markdown]
# ## Código utilizado para análise de dados da reportagem: [As cidades brasileiras que há mais de 20 anos só elegem homens para prefeito, vice e vereador](https://g1.globo.com/politica/eleicoes/2024/eleicao-em-numeros/noticia/2024/10/19/as-cidades-brasileiras-que-ha-mais-de-20-anos-so-elegem-homens-para-prefeito-vice-e-vereador.ghtml)

# %%
# Importa as bibliotecas necessárias para a análise
import pandas as pd
import numpy as np
import re
import numpy as np
import os

# %%
# Me mostre tudo
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## 📅 2020

# %%
# Definindo as colunas do df
colunas_desejadas = ['SG_UE', 'DS_SIT_TOT_TURNO', 'NM_CANDIDATO', 'NM_URNA_CANDIDATO', 'SG_UF', 'NM_UE', 'SG_PARTIDO', 'DS_GENERO', 'DS_CARGO']

# Lendo o arquivo CSV apenas com as colunas especificadas
df_2000 = pd.read_csv("data/consulta_cand_2000_BRASIL.csv", delimiter=';', encoding='latin-1', usecols=colunas_desejadas)

# %%
df_2000.head()
# Out:
#   SG_UF  SG_UE          NM_UE  DS_CARGO                  NM_CANDIDATO  \
# 0    BA  36170         ITAMBE  VEREADOR        PAULO RUCAS BRITO ACHY
# 1    SC  80551        BRUSQUE  VEREADOR               EDEMIR DE SOUZA
# 2    SP  63614          COTIA  VEREADOR          WAGNER LUIS DO PRADO
# 3    BA  37150          MARAU  VEREADOR       VALQUÍRIA DE LEMOS MELO
# 4    SC  81051  FLORIANOPOLIS  VEREADOR  ALVARO LUIZ BORTOLOTTO PREIS
#
#               NM_URNA_CANDIDATO SG_PARTIDO  DS_GENERO DS_SIT_TOT_TURNO
# 0                            TO       PMDB  MASCULINO           ELEITO
# 1            EDEMIR ELETRECISTA        PDT  MASCULINO         SUPLENTE
# 2                       TRILILI       PRTB  MASCULINO         SUPLENTE
# 3                     VALQUÍRIA         PL   FEMININO         SUPLENTE
# 4  ÁLVARO LUIZ BORTOLOTTO PREIS       PSDB  MASCULINO         SUPLENTE

# %%
df_2000 = df_2000[df_2000['DS_SIT_TOT_TURNO'].isin(['ELEITO', 'ELEITO POR MÉDIA'])]

# %%
mulheres_eleitas = df_2000[(df_2000['DS_GENERO'] == 'FEMININO')]

# %%
# Obter SG_UE das cidades que elegeram mulheres
sg_ue_com_mulheres = mulheres_eleitas['SG_UE'].unique()

# %%
# Obter todas as cidades (SG_UF, SG_UE, NM_UE)
cidades_completas = df_2000[['SG_UF', 'SG_UE', 'NM_UE']].drop_duplicates()

# %%
cidades_sem_mulheres_2000 = cidades_completas[~cidades_completas['SG_UE'].isin(sg_ue_com_mulheres)]

# %% [markdown]
# ## 📅 2004

# %%
# Definir as colunas que você deseja ler
colunas_desejadas = ['SG_UE', 'DS_SIT_TOT_TURNO', 'NM_CANDIDATO', 'NM_URNA_CANDIDATO', 'SG_UF', 'NM_UE', 'SG_PARTIDO', 'DS_GENERO', 'DS_CARGO']

# Ler o arquivo CSV apenas com as colunas especificadas
df_2004 = pd.read_csv("data/consulta_cand_2004_BRASIL.csv", delimiter=';', encoding='latin-1', usecols=colunas_desejadas)

# %%
df_2004.head()
# Out:
#   SG_UF  SG_UE           NM_UE  DS_CARGO                   NM_CANDIDATO  \
# 0    PA   5738  RONDON DO PARA  VEREADOR    JOSÉ MARIA RICARDO DA SILVA
# 1    PA   5630           VIGIA  VEREADOR  JOSÉ ARNALDO DE ALMEIDA COSTA
# 2    PA   5193         PRAINHA  VEREADOR         LEONAM MENDES DA SILVA
# 3    MG  49590  PATOS DE MINAS  VEREADOR       RUBENS CANDIDO DE AQUINO
# 4    MG  42790   CARMO DA MATA  VEREADOR      JOAQUIM CUSTODIO SOBRINHO
#
#   NM_URNA_CANDIDATO SG_PARTIDO  DS_GENERO  \
# 0        JOSÉ MARIA        PTB  MASCULINO
# 1          CALAFATE      PRONA  MASCULINO
# 2            LEONAM        PPS  MASCULINO
# 3    RUBENS CANDIDO         PL  MASCULINO
# 4          CAQUINHO        PDT  MASCULINO
#
#                                  DS_SIT_TOT_TURNO
# 0                                      NÃO ELEITO
# 1                                      NÃO ELEITO
# 2                                        SUPLENTE
# 3                                      NÃO ELEITO
# ...

# %%
df_2004 = df_2004[df_2004['DS_SIT_TOT_TURNO'].isin(['ELEITO', 'MÉDIA'])]

# %%
mulheres_eleitas = df_2004[(df_2004['DS_GENERO'] == 'FEMININO')]

# %%
# Obter SG_UE das cidades que elegeram mulheres
sg_ue_com_mulheres = mulheres_eleitas['SG_UE'].unique()

# %%
# Obter todas as cidades (SG_UF, SG_UE, NM_UE)
cidades_completas = df_2004[['SG_UF', 'SG_UE', 'NM_UE']].drop_duplicates()

# %%
cidades_sem_mulheres_2004 = cidades_completas[~cidades_completas['SG_UE'].isin(sg_ue_com_mulheres)]

# %% [markdown]
# ## 📅 2008

# %%
# Definir as colunas que você deseja ler
colunas_desejadas = ['SG_UE', 'DS_SIT_TOT_TURNO', 'NM_CANDIDATO', 'NM_URNA_CANDIDATO', 'SG_UF', 'NM_UE', 'SG_PARTIDO', 'DS_GENERO']

# Ler o arquivo CSV apenas com as colunas especificadas
df_2008 = pd.read_csv("data/consulta_cand_2008_BRASIL.csv", delimiter=';', encoding='latin-1', usecols=colunas_desejadas)

# %%
df_2008.head()
# Out:
#   SG_UF  SG_UE               NM_UE                      NM_CANDIDATO  \
# 0    MG  42501     VARJÃO DE MINAS          ANTONIO ILSON DOS SANTOS
# 1    MG  40606           RIACHINHO  IRENE RODRIGUES DA SILVA CARDOSO
# 2    SC  82295             ORLEANS                   FERNANDO ASCARI
# 3    PA   5452  SÃO FÉLIX DO XINGU             TARCISIO COELHO FILHO
# 4    MG  43990        CÓRREGO NOVO         WILSON RODRIGUES DA COSTA
#
#         NM_URNA_CANDIDATO SG_PARTIDO  DS_GENERO DS_SIT_TOT_TURNO
# 0           ANTONIO ILSON         PP  MASCULINO           #NULO#
# 1                   IRENE       PSDB   FEMININO         SUPLENTE
# 2  FERNANDO ASCARI VIEIRA        DEM  MASCULINO         SUPLENTE
# 3                TARCISIO         PT  MASCULINO         SUPLENTE
# 4            WILSON GORDO       PRTB  MASCULINO         SUPLENTE

# %%
df_2008 = df_2008[df_2008['DS_SIT_TOT_TURNO'].isin(['ELEITO', 'MÉDIA'])]

# %%
mulheres_eleitas = df_2008[(df_2008['DS_GENERO'] == 'FEMININO')]

# %%
# Obter SG_UE das cidades que elegeram mulheres
sg_ue_com_mulheres = mulheres_eleitas['SG_UE'].unique()

# %%
# Obter todas as cidades (SG_UF, SG_UE, NM_UE)
cidades_completas = df_2008[['SG_UF', 'SG_UE', 'NM_UE']].drop_duplicates()

# %%
cidades_sem_mulheres_2008 = cidades_completas[~cidades_completas['SG_UE'].isin(sg_ue_com_mulheres)]

# %% [markdown]
# ## 📅 2012

# %%
# Definir as colunas que você deseja ler
colunas_desejadas = ['SG_UE', 'DS_SIT_TOT_TURNO', 'NM_CANDIDATO', 'NM_URNA_CANDIDATO', 'SG_UF', 'NM_UE', 'SG_PARTIDO', 'DS_GENERO']

# Ler o arquivo CSV apenas com as colunas especificadas
df_2012 = pd.read_csv("data/consulta_cand_2012_BRASIL.csv", delimiter=';', encoding='latin-1', usecols=colunas_desejadas)

# %%
df_2012.head()
# Out:
#   SG_UF  SG_UE                   NM_UE                  NM_CANDIDATO  \
# 0    ES  56170  BARRA DE SÃO FRANCISCO    PEDRINHO GODOY DE OLIVEIRA
# 1    MA   7455                 CAJAPIÓ      PEDROLINA DE JESUS PINTO
# 2    GO  92274    APARECIDA DE GOIÂNIA      ALBANICE FERREIRA DA CUZ
# 3    MA   9474           VARGEM GRANDE             ENEAS SOUSA COSTA
# 4    GO  94250               ITUMBIARA  ONEIDA MARIA DO CARMO ARAUJO
#
#   NM_URNA_CANDIDATO SG_PARTIDO  DS_GENERO DS_SIT_TOT_TURNO
# 0    PEDRINHO GODOY    PT do B  MASCULINO       NÃO ELEITO
# 1         PEDROLINA    PC do B   FEMININO         SUPLENTE
# 2          ALBANICE        PPL   FEMININO           #NULO#
# 3             ENEAS        PTB  MASCULINO         SUPLENTE
# 4  ONEIDA DA CAMARA        PHS   FEMININO         SUPLENTE

# %%
df_2012 = df_2012[df_2012['DS_SIT_TOT_TURNO'].isin(['ELEITO', 'ELEITO POR MÉDIA', 'ELEITO POR QP'])]

# %%
mulheres_eleitas = df_2012[(df_2012['DS_GENERO'] == 'FEMININO')]

# %%
# Obter SG_UE das cidades que elegeram mulheres
sg_ue_com_mulheres = mulheres_eleitas['SG_UE'].unique()

# %%
# Obter todas as cidades (SG_UF, SG_UE, NM_UE)
cidades_completas = df_2012[['SG_UF', 'SG_UE', 'NM_UE']].drop_duplicates()

# %%
cidades_sem_mulheres_2012 = cidades_completas[~cidades_completas['SG_UE'].isin(sg_ue_com_mulheres)]

# %% [markdown]
# ## 📅 2016

# %%
# Definir as colunas que você deseja ler
colunas_desejadas = ['SG_UE', 'DS_SIT_TOT_TURNO', 'NM_CANDIDATO', 'NM_URNA_CANDIDATO', 'SG_UF', 'NM_UE', 'SG_PARTIDO', 'DS_GENERO']

# Ler o arquivo CSV apenas com as colunas especificadas
df_2016 = pd.read_csv("data/consulta_cand_2016_BRASIL.csv", delimiter=';', encoding='latin-1', usecols=colunas_desejadas)

# %%
df_2016.head()
# Out:
#   SG_UF  SG_UE         NM_UE                      NM_CANDIDATO  \
# 0    MA   7439  BURITI BRAVO  MARIA SOLIDADE COSME DE OLIVEIRA
# 1    PI  11231  MIGUEL ALVES          FRANCINETE ALVES ALMEIDA
# 2    PI  11231  MIGUEL ALVES            IVANILDO SOUSA MOREIRA
# 3    PI  11231  MIGUEL ALVES             INÁCIO ALVES DA SILVA
# 4    SP  65196       IPAUSSU                 WILSON DE ANDRADE
#
#     NM_URNA_CANDIDATO SG_PARTIDO  DS_GENERO DS_SIT_TOT_TURNO
# 0                XUXA        PTB   FEMININO         SUPLENTE
# 1          FRANCINETE        DEM  MASCULINO         SUPLENTE
# 2  PROFESSOR IVANILDO         PP  MASCULINO         SUPLENTE
# 3              INÁCIO         PP  MASCULINO         SUPLENTE
# 4             PAQUITO         PP  MASCULINO           #NULO#

# %%
df_2016 = df_2016[df_2016['DS_SIT_TOT_TURNO'].isin(['ELEITO', 'ELEITO POR MÉDIA', 'ELEITO POR QP'])]

# %%
mulheres_eleitas = df_2016[(df_2016['DS_GENERO'] == 'FEMININO')]

# %%
# Obter SG_UE das cidades que elegeram mulheres
sg_ue_com_mulheres = mulheres_eleitas['SG_UE'].unique()

# %%
# Obter todas as cidades (SG_UF, SG_UE, NM_UE)
cidades_completas = df_2016[['SG_UF', 'SG_UE', 'NM_UE']].drop_duplicates()

# %%
cidades_sem_mulheres_2016 = cidades_completas[~cidades_completas['SG_UE'].isin(sg_ue_com_mulheres)]

# %% [markdown]
# ## 📅 2020

# %%
# Definir as colunas que você deseja ler
colunas_desejadas = ['SG_UE', 'DS_SIT_TOT_TURNO', 'NM_CANDIDATO', 'NM_URNA_CANDIDATO', 'SG_UF', 'NM_UE', 'SG_PARTIDO', 'DS_GENERO']

# Ler o arquivo CSV apenas com as colunas especificadas
df_2020 = pd.read_csv("data/consulta_cand_2020_BRASIL.csv", delimiter=';', encoding='latin-1', usecols=colunas_desejadas)

# %%
df_2020.head()
# Out:
#   SG_UF  SG_UE                    NM_UE                       NM_CANDIDATO  \
# 0    SP  69833      RIO GRANDE DA SERRA          RICARDO AKIRA ONO AURIANI
# 1    PE  24570  JABOATÃO DOS GUARARAPES          FABIO ANDRADE DE OLIVEIRA
# 2    PE  24570  JABOATÃO DOS GUARARAPES  EDILEUZA ROSA SILVA DO NASCIMENTO
# 3    PB  20478                  JACARAÚ           LUCINEIDE GOMES DA SILVA
# 4    RJ  58360                   TANGUÁ               MARCILEA BRAGA MATOS
#
#    NM_URNA_CANDIDATO SG_PARTIDO  DS_GENERO DS_SIT_TOT_TURNO
# 0      AKIRA AURIANI        PSB  MASCULINO           #NULO#
# 1      FABIO ANDRADE       PROS  MASCULINO           #NULO#
# 2  LEU DO DOM HELDER       PRTB   FEMININO           #NULO#
# 3         NINA GOMES         PV   FEMININO           #NULO#
# 4       MARCIA MATOS        PSL   FEMININO    ELEITO POR QP

# %%
df_2020 = df_2020[df_2020['DS_SIT_TOT_TURNO'].isin(['ELEITO', 'ELEITO POR MÉDIA', 'ELEITO POR QP'])]

# %%
mulheres_eleitas = df_2020[(df_2020['DS_GENERO'] == 'FEMININO')]

# %%
# Obter SG_UE das cidades que elegeram mulheres
sg_ue_com_mulheres = mulheres_eleitas['SG_UE'].unique()

# %%
# Obter todas as cidades (SG_UF, SG_UE, NM_UE)
cidades_completas = df_2020[['SG_UF', 'SG_UE', 'NM_UE']].drop_duplicates()

# %%
cidades_sem_mulheres_2020 = cidades_completas[~cidades_completas['SG_UE'].isin(sg_ue_com_mulheres)]

# %% [markdown]
# ## 📅 2024

# %%
# Definir as colunas que você deseja ler
colunas_desejadas = ['SG_UE', 'DS_SIT_TOT_TURNO', 'NM_CANDIDATO', 'NM_URNA_CANDIDATO', 'SG_UF', 'NM_UE', 'SG_PARTIDO', 'DS_GENERO']

# Ler o arquivo CSV apenas com as colunas especificadas
df_2024 = pd.read_csv("data/consulta_cand_2024_BRASIL.csv", delimiter=';', encoding='latin-1', usecols=colunas_desejadas)

# %%
df_2024.head()
# Out:
#   SG_UF  SG_UE    NM_UE                         NM_CANDIDATO  \
# 0    AM   2712   PAUINI                MANOEL NUNES DA SILVA
# 1    MG  45411   FRUTAL  MARIA EDUARDA BATISTA CANDIDO PEPPE
# 2    MG  46477  ITAJUBÁ             LUÍS HENRIQUE DOS SANTOS
# 3    CE  15016  PALHANO            ANANIAS FERREIRA DE SOUSA
# 4    MG  41998    CAETÉ       ARLISSON PAULINELLI DOS SANTOS
#
#              NM_URNA_CANDIDATO SG_PARTIDO  DS_GENERO DS_SIT_TOT_TURNO
# 0           MANOEL SERINGUEIRO         PT  MASCULINO       NÃO ELEITO
# 1              EDUARDA BATISTA       PODE   FEMININO       NÃO ELEITO
# 2  LUÍS FILHO DO ZÉ BRAZÓPOLIS         PL  MASCULINO       NÃO ELEITO
# 3                      ANANIAS      UNIÃO  MASCULINO       NÃO ELEITO
# 4             AZIA DO COQUINHO        PDT  MASCULINO       NÃO ELEITO

# %%
df_2024 = df_2024[df_2024['DS_SIT_TOT_TURNO'].isin(['ELEITO', 'ELEITO POR MÉDIA', 'ELEITO POR QP'])]

# %%
mulheres_eleitas = df_2024[(df_2024['DS_GENERO'] == 'FEMININO')]

# %%
# Obter SG_UE das cidades que elegeram mulheres
sg_ue_com_mulheres = mulheres_eleitas['SG_UE'].unique()

# %%
# Obter todas as cidades (SG_UF, SG_UE, NM_UE)
cidades_completas = df_2024[['SG_UF', 'SG_UE', 'NM_UE']].drop_duplicates()

# %%
cidades_sem_mulheres_2024 = cidades_completas[~cidades_completas['SG_UE'].isin(sg_ue_com_mulheres)]

# %% [markdown]
# ## 🔎 Procurando as cidades sem mulheres

# %%
tabelas = [cidades_sem_mulheres_2000, cidades_sem_mulheres_2004, cidades_sem_mulheres_2008,
           cidades_sem_mulheres_2012, cidades_sem_mulheres_2016, cidades_sem_mulheres_2020, cidades_sem_mulheres_2024]

# Iniciar com a primeira tabela
primeira_tabela = tabelas[0][['SG_UF', 'SG_UE', 'NM_UE']]

# Cruzar com as demais tabelas, incluindo SG_UF
for i, tabela in enumerate(tabelas[1:], start=1):
    df_final = pd.merge(primeira_tabela, tabela[['SG_UF', 'SG_UE', 'NM_UE']], on=['SG_UF', 'SG_UE'], how='inner', suffixes=(f'', f'_ano_{i}'))

# %%
df_final
# Out:
#     SG_UF  SG_UE                         NM_UE                   NM_UE_ano_6
# 0      MG  40827                     SEM-PEIXE                     SEM PEIXE
# 1      RJ  58718                     PARACAMBI                     PARACAMBI
# 2      RS  98299                          JOIA                          JÓIA
# 3      RS  89435                       TRIUNFO                       TRIUNFO
# 4      MG  40932                       ATALEIA                       ATALÉIA
# 5      RO    515       NOVO HORIZONTE DO OESTE       NOVO HORIZONTE DO OESTE
# 6      SC  81310               HERVAL DO OESTE                HERVAL D'OESTE
# 7      MG  40541       PEDRAS DE MARIA DA CRUZ       PEDRAS DE MARIA DA CRUZ
# 8      TO  73539  SANTA TEREZINHA DO TOCANTINS  SANTA TEREZINHA DO TOCANTINS
# 9      BA  39632                     VERA CRUZ                     VERA CRUZ
# 10     PR  78352              SALTO DO ITARARE              SALTO DO ITARARÉ
# ...

# %% [markdown]
# ### 💡 Todas as cidades acima tiveram uma segundo checagem para validação, com envio de emails e pesquisa em jornais antigos sobre a presença de mulheres na política.
